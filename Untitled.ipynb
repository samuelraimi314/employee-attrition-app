# %%
# Using pickle directly
import pickle

file_path = r"C:\Users\USER\Documents\practice csv\employee-attrition-project\best_rf.pkl"

with open(file_path, "rb") as f:  # note "rb" = read binary
    best_rf = pickle.load(f)

print(best_rf)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=4, random_state=42)

# %%
# Example: predicting on a new sample
import pandas as pd

# Create a sample input (must match your model's features)
sample = pd.DataFrame({
    "Age": [30],
    "DailyRate": [1200],
    "DistanceFromHome": [5],
    "Education": [3],
    "JobLevel": [2],
    "MonthlyIncome": [5000],
    "NumCompaniesWorked": [1],
    "PercentSalaryHike": [12],
    "TotalWorkingYears": [7],
    "YearsAtCompany": [3],
    "YearsInCurrentRole": [2],
    "YearsSinceLastPromotion": [1],
    "YearsWithCurrManager": [2]
})

# Predict attrition
prediction = best_rf.predict(sample)
print("Prediction:", prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 22
#       5 sample = pd.DataFrame({
#       6     "Age": [30],
#       7     "DailyRate": [1200],
#    (...)
#      18     "YearsWithCurrManager": [2]
#      19 })
#      21 # Predict attrition
# ---> 22 prediction = best_rf.predict(sample)
#      23 print("Prediction:", prediction)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:903, in ForestClassifier.predict(self, X)
#     882 def predict(self, X):
#     883     """
#     884     Predict class for X.
#     885
#    (...)
#     901         The predicted classes.
#     902     """
# --> 903     proba = self.predict_proba(X)
#     905     if self.n_outputs_ == 1:
#     906         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# ...

# %%
print(best_rf.feature_names_in_)
# Out:
# ['Age' 'DistanceFromHome' 'MonthlyIncome' 'TotalWorkingYears'
#  'YearsAtCompany' 'YearsInCurrentRole' 'JobSatisfaction'
#  'EnvironmentSatisfaction' 'WorkLifeBalance' 'OverTime_flag'
#  'tenure_ratio' 'engagement_index' 'PercentSalaryHike' 'overtime_low_hike']

# %%
import pandas as pd

# Create a sample row with all required features
sample = pd.DataFrame([{
    "Age": 30,
    "DistanceFromHome": 5,
    "MonthlyIncome": 5000,
    "TotalWorkingYears": 8,
    "YearsAtCompany": 3,
    "YearsInCurrentRole": 2,
    "JobSatisfaction": 4,
    "EnvironmentSatisfaction": 3,
    "WorkLifeBalance": 3,
    "OverTime_flag": 1,        # 1 = Yes, 0 = No
    "tenure_ratio": 0.5,
    "engagement_index": 0.75,
    "PercentSalaryHike": 15,
    "overtime_low_hike": 0     # depends on your feature engineering
}])

# Predict attrition
prediction = best_rf.predict(sample)
print("Prediction:", prediction)

# Optional: probability of each class
probabilities = best_rf.predict_proba(sample)
print("Probability of each class:", probabilities)
# Out:
# Prediction: [0]
# Probability of each class: [[0.51287489 0.48712511]]

# %%
import pickle
import pandas as pd

# Load trained Random Forest
with open("best_rf.pkl", "rb") as f:
    best_rf = pickle.load(f)

# Load SHAP explainer
with open("explainer.pkl", "rb") as f:
    explainer = pickle.load(f)

# %%
employee_df = pd.DataFrame({
    "Age": [35],
    "MonthlyIncome": [6000],
    "OverTime_flag": [1],  # 1 = Yes, 0 = No
    "YearsAtCompany": [5],
    "TotalWorkingYears": [10],
    "JobSatisfaction": [3],
    "WorkLifeBalance": [3]
    # Add other features as in your trained model
})

# %%
risk = best_rf.predict_proba(employee_df)[:,1][0]
print(f"Predicted attrition risk: {risk*100:.1f}%")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 risk = best_rf.predict_proba(employee_df)[:,1][0]
#       2 print(f"Predicted attrition risk: {risk*100:.1f}%")
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:945, in ForestClassifier.predict_proba(self, X)
#     943 check_is_fitted(self)
#     944 # Check data
# --> 945 X = self._validate_X_predict(X)
#     947 # Assign chunk of trees to jobs
#     948 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:637, in BaseForest._validate_X_predict(self, X)
#     634 else:
#     635     ensure_all_finite = True
# --> 637 X = validate_data(
#     638     self,
#     639     X,
#     640     dtype=DTYPE,
#     641     accept_sparse="csr",
#     642     reset=False,
# ...

# %%
feature_names = X_train.columns  # or however you saved your training features
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 feature_names = X_train.columns
#
# NameError: name 'X_train' is not defined
